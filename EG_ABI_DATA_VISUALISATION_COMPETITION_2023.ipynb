# %% [markdown]
# <a href="https://colab.research.google.com/github/ogunsegun/-QHack2023_OGUNTUNNBI-SEGUN/blob/main/EG_ABI_DATA_VISUALISATION_COMPETITION_2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
url = 'https://pkgstore.datahub.io/core/global-temp/annual_csv/data/a26b154688b061cdd04f1df36e4408be/annual_csv.csv'
df = pd.read_csv(url)
df.head()
# Out:
#     Source  Year    Mean
# 0     GCAG  2016  0.9363
# 1  GISTEMP  2016  0.9900
# 2     GCAG  2015  0.8998
# 3  GISTEMP  2015  0.8700
# 4     GCAG  2014  0.7408
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Year'].plot(kind='hist', bins=20, title='Year')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Mean'].plot(kind='hist', bins=20, title='Mean')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_2.groupby('Source').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %% [markdown]
# https://datahub.io/core/global-temp#pandas

# %% [markdown]
# # New section

# %%
url = '/content/epa-sea-level_csv.csv'
df = pd.read_csv(url)
df.head(134)
# Out:
#            Year  CSIRO Adjusted Sea Level  Lower Error Bound  \
# 0    1880-03-15                  0.000000          -0.952756
# 1    1881-03-15                  0.220472          -0.732283
# 2    1882-03-15                 -0.440945          -1.346457
# 3    1883-03-15                 -0.232283          -1.129921
# 4    1884-03-15                  0.590551          -0.283465
# ..          ...                       ...                ...
# 129  2009-03-15                  8.586614           8.311024
# 130  2010-03-15                  8.901575           8.618110
# 131  2011-03-15                  8.964567           8.661417
# 132  2012-03-15                  9.326772           8.992126
# 133  2013-03-15                  8.980315           8.622047
#
#      Upper Error Bound  NOAA Adjusted Sea Level
# 0             0.952756                      NaN
# 1             1.173228                      NaN
# 2             0.464567                      NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 135 entries, 0 to 134
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Year                      135 non-null    object
#  1   CSIRO Adjusted Sea Level  134 non-null    float64
#  2   Lower Error Bound         134 non-null    float64
#  3   Upper Error Bound         134 non-null    float64
#  4   NOAA Adjusted Sea Level   22 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 5.4+ KB
